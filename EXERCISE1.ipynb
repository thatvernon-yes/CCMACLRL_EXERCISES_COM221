# %% [markdown]
# <a href="https://colab.research.google.com/github/thatvernon-yes/CCMACLRL_EXERCISES_COM222/blob/main/EXERCISE1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EXERCISE 1

# %%
# !pip install pandas
# !pip install matplotlib

# %%
def printname(Fname) :
  print(Fname)

# %%
printname("Vernon")
# Out:
# Vernon

# %% [markdown]
# #LISTS

# %%
fruits = ["apple", "banana","orange","lemon"]

# %%
#fruits
print(fruits)
for i in fruits:
  print(i)
# Out:
# ['apple', 'banana', 'orange', 'lemon']
# apple
# banana
# orange
# lemon

# %% [markdown]
# List Comprehension

# %%
duplicate = [x for x in fruits if "e" in x]
duplicate
# Out:
# ['apple', 'orange', 'lemon']

# %% [markdown]
# #MAP

# %%
myNums = [1,2,3,4,5]

# %%
def multiplybyTwo(num):
  return num * 2

# %%
myNewNums = list (map(multiplybyTwo, myNums))
myNewNums
# Out:
# [2, 4, 6, 8, 10]

# %% [markdown]
# #PANDAS

# %%
import pandas as pd

# %%
dataframe = pd.read_excel("SAMPLE.xlsx")

# %%
dataframe
# Out:
#    HEIGH T  WEIGHT   AGE
# 0      133       71   22
# 1      143       90   22
# 2      153       74   22
# 3      153       54   22
# 4      151       47   25
# 5      148       45   21
# 6      166       57   18
# 7      167       74   22
# 8      130       62   20
# 9      130       86   18

# %%
dataframe.head()
# Out:
#    HEIGH T  WEIGHT   AGE
# 0      133       71   22
# 1      143       90   22
# 2      153       74   22
# 3      153       54   22
# 4      151       47   25

# %%
dataframe.tail()
# Out:
#    HEIGH T  WEIGHT   AGE
# 5      148       45   21
# 6      166       57   18
# 7      167       74   22
# 8      130       62   20
# 9      130       86   18

# %%
dataframe.value_counts()
# Out:
# HEIGH T  WEIGHT   AGE
# 130      62       20     1
#          86       18     1
# 133      71       22     1
# 143      90       22     1
# 148      45       21     1
# 151      47       25     1
# 153      54       22     1
#          74       22     1
# 166      57       18     1
# 167      74       22     1
# Name: count, dtype: int64

# %%
dataframe.drop_duplicates(inplace = True)

# %%
dataframe.iloc[0]
# Out:
# HEIGH T    133
# WEIGHT      71
# AGE         22
# Name: 0, dtype: int64

# %%
dataframe.describe()
# Out:
#           HEIGH T    WEIGHT         AGE
# count   10.000000  10.000000  10.000000
# mean   147.400000  66.000000  21.200000
# std     13.492385  15.534907   2.097618
# min    130.000000  45.000000  18.000000
# 25%    135.500000  54.750000  20.250000
# 50%    149.500000  66.500000  22.000000
# 75%    153.000000  74.000000  22.000000
# max    167.000000  90.000000  25.000000

# %%
dataframe.drop(columns = ["AGE"])
# Out:
#    HEIGH T  WEIGHT
# 0      133       71
# 1      143       90
# 2      153       74
# 3      153       54
# 4      151       47
# 5      148       45
# 6      166       57
# 7      167       74
# 8      130       62
# 9      130       86

# %%
dataframe
# Out:
#    HEIGH T  WEIGHT   AGE
# 0      133       71   22
# 1      143       90   22
# 2      153       74   22
# 3      153       54   22
# 4      151       47   25
# 5      148       45   21
# 6      166       57   18
# 7      167       74   22
# 8      130       62   20
# 9      130       86   18

# %%
#dataframe.drop(columns = ["AGE"], inplace = TRUE )1  #will make the drop official

# %% [markdown]
# ##MATPLOTLIB

# %%
from matplotlib import pyplot as plt

# %%
X1 = [1,2,3,4,5]

# %%
plt.plot(X1)
plt.show()

# %%
X2 = [6,7,8,9,10]

# %%
plt.plot(X1)
plt.plot(X2)
plt.show()

# %%
Y = [10,11,12,13,14]
plt.plot(X1,Y)

# %%
Y = [10,11,12,13,14]
plt.plot(dataframe["HEIGH T"], dataframe["AGE"], marker = 'o', color = "green", linestyle = "dotted")
plt.grid(axis = 'x') #plt.grid() both x and y axis is visible
plt.title("My Plot")
plt.ylabel("AGE")
plt.xlabel("HEIGHT")
# Out:
# Text(0.5, 0, 'HEIGHT')
